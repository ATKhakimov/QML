# %% [markdown]
# <a href="https://colab.research.google.com/github/ATKhakimov/QML/blob/main/HW1_Khakimov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %%
data = pd.read_excel('end_seminar.xlsx')
data.info()
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      361 non-null    datetime64[ns]
#  1   id             361 non-null    object
#  2   rating         361 non-null    int64
#  3   18_group       223 non-null    float64
#  4   is_mi          18 non-null     float64
#  5   fall_1         361 non-null    object
#  6   fall_2         361 non-null    object
#  7   fall_3         361 non-null    object
#  8   spring_1       361 non-null    object
#  9   spring_2       361 non-null    object
#  10  spring_3       361 non-null    object
#  11  is_first_time  359 non-null    object
#  12  percentile     361 non-null    float64
#  13  17_group       138 non-null    float64
#  14  blended        138 non-null    object
#  15  is_ml_student  57 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# ...

# %%
pd.isnull(data)
data.isnull().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %%
for col in data:
    if (data[col].dtype == int64 or data[col].dtype == float64):
      data[col].fillna(value = 0)
    if data[col].dtype == object:
      data[col].fillna("1") 
    data["17_group"].fillna(0) 
data.isnull().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
data.groupby('blended').count()
# Out:
#                                        timestamp  id  rating  18_group  is_mi  \
# blended
# DevOps                                        91  91      91         0      0
# Введение в дифференциальную геометрию         15  15      15         0      0
# Соревновательный анализ данных                32  32      32         0      0
#
#                                        fall_1  fall_2  fall_3  spring_1  \
# blended
# DevOps                                     91      91      91        91
# Введение в дифференциальную геометрию      15      15      15        15
# Соревновательный анализ данных             32      32      32        32
#
#                                        spring_2  spring_3  is_first_time  \
# blended
# DevOps                                       91        91             91
# Введение в дифференциальную геометрию        15        15             15
# Соревновательный анализ данных               32        32             31
#
# ...

# %%
data[data['17_group'] == 171.0]

# %%
data["Task7"] = 1
for i in range (361):
  if ((data.iloc[i]['17_group'] == 171.0) | (data.iloc[i]['17_group'] == 172.0) | (data.iloc[i]['17_group'] == 173.0) | (data.iloc[i]['is_mi'] == 1.0)):
    data.loc[i,'Task7'] = 2
T7 = data['Task7']

# %%
data['dates'] = data['timestamp'].dt.date
data.groupby('dates').count()
# Out:
#             timestamp   id  rating  18_group  is_mi  fall_1  fall_2  fall_3  \
# dates
# 2020-05-14         18   18      18         0      0      18      18      18
# 2020-05-15         31   31      31        27      0      31      31      31
# 2020-05-16         16   16      16        13      1      16      16      16
# 2020-05-17         38   38      38        17      1      38      38      38
# 2020-05-18        235  235     235       150     15     235     235     235
# 2020-05-19         14   14      14        10      1      14      14      14
# 2020-05-20          4    4       4         3      0       4       4       4
# 2020-05-21          1    1       1         1      0       1       1       1
# 2020-05-23          2    2       2         0      0       2       2       2
# 2020-05-24          2    2       2         2      0       2       2       2
#
#             spring_1  spring_2  spring_3  is_first_time  percentile  17_group  \
# dates
# ...

# %%
data[['dates', 'rating']]

# %%
agg_func = {
    'rating': ['mean']
}
data1 = data.groupby(['dates']).agg(agg_func)
print(data1.columns)
# Out:
# MultiIndex([('rating', 'mean')],
#            )

# %%
data1.unstack().plot()
